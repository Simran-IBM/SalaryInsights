# %% [markdown]
# # Predict Salary

# %% [markdown]
# ## Importing the Python libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns 
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
from sklearn import metrics

from sklearn.preprocessing import LabelEncoder

import os

import math

# %matplotlib inline

# %% [markdown]
# ## Dataset
# ### Set raw data file path
# ### Reading the data sheet

# %%
raw_file_path = os.path.join(os.path.pardir, 'data', 'raw')
raw_data_file_path = os.path.join(raw_file_path, 'salary_data_1.xlsx')

raw_data = pd.read_excel(raw_data_file_path)

# %% [markdown]
# ## Explore Data
# ### Get a sneak peak

# %%
raw_data.head(10)
# Out:
#      Age                                           Industry  \
# 0  18-24                                           Hospital
# 1  18-24                               on-campus employment
# 2  18-24                              Images and Data Entry
# 3  35-44                                      Retail Gocery
# 4  18-24  Currently a student, but I work in my drama de...
# 5  18-24                                        County govt
# 6  18-24                                           Software
# 7  55-64                                            Grocery
# 8  25-34                                           Academia
# 9  55-64                                   graphic designer
#
#                  Generic Job Title  Salary Currency  Experience Gender
# 0  Medical Laboratory Technologist  1000.0      USD           1   Male
# 1          Borrow Direct Assistant  2000.0      USD           1   Male
# 2    Seasonal data entry associate  2000.0      USD           1   Male
# 3                        Superviso  2240.0      USD          11   Male
# 4    Theatrical Journeyman/student  2900.0      USD           1   Male
# 5                           Intern  3000.0      USD           1   Male
# 6               Software developer  3000.0      USD           4   Male
# 7                Front end cashier  3150.0      USD          11   Male
# 8                          Adjunct  3500.0      USD           6   Male
# 9                 graphic designer  3500.0      USD          22   Male

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877 entries, 0 to 876
# Data columns (total 7 columns):
# Age                  877 non-null object
# Industry             841 non-null object
# Generic Job Title    877 non-null object
# Salary               877 non-null float64
# Currency             877 non-null object
# Experience           877 non-null int64
# Gender               877 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 48.0+ KB

# %%
print(raw_data['Generic Job Title'])
# Out:
# 0                Medical Laboratory Technologist
# 1                        Borrow Direct Assistant
# 2                  Seasonal data entry associate
# 3                                      Superviso
# 4                  Theatrical Journeyman/student
# 5                                         Intern
# 6                             Software developer
# 7                              Front end cashier
# 8                                        Adjunct
# 9                               graphic designer
# 10                            Research Assistant
# 11              Collection Development Librarian
# 12                              Office Assistant
# 13                                  Receptionist
# 14                                    Line cook
# 15                      Study start-up associate
# 16                      Study start-up associate
# 17                              Prison Librarian
# 18                                     Paralegal
# 19                            Teachers Assistant
# 20                      Administrative Assistant
# 21                                          Host
# 22                               Swim instructor
# 23                                 Writing tutor
# 24                                 Writing Tutor
# 25                                        Waiter
# 26                             Interior designer
# 27                 Distance Learning Facilitator
# 28                         journalist / reporter
# 29                         journalist / reporter
#                          ...
# 847                           Shipping associate
# 848                         Social Media Manager
# 849                                   Specialist
# 850                                   Specialist
# 851                  Speech-Language Pathologist
# 852                                Staff writer
# 853                                store manager
# 854                                     stripper
# 855                                   Sushi Chef
# 856                        Systems Administrator
# 857              Teaching Assistant, PhD student
# 858                                 Tech Support
# 859                                        Tutor
# 860                                     Vet tech
# 861                        Veterinary Technician
# 862                      Web & Marketing Manager
# 863                              Wedding Planner
# 864                         Programs Coordinator
# 865                            Library Assistant
# 866                                   Data Clerk
# 867                      Maintenance Coordinator
# 868                         Graduate Coordinator
# 869                     Administrative Assistant
# 870                   Instructional Technologist
# 871                   Student Records Specialist
# 872                          Program Coordinator
# 873                          Billing specialist
# 874                              Library Manager
# 875    Administrative and Purchasing Coordinator
# 876                             Assistant Brewer
# Name: Generic Job Title, Length: 877, dtype: object

# %% [markdown]
# ### Generalising the job titles into categories

# %%
def GetJobTitle(jobtitle):
    engineer = ["engineer", "analyst", "animator", "data scientist","technician", "engineering", "qa", "quality","tech", 
                 "control", "software","consultant", "designer", "developer", "specialist"]
    account = ["account", "claims"]
    hr  = ["talent", "hr", "recruiting", "recruiter", "human", "resources"]
    scientist = ["scientist", "research", "r&d", "technologist", "pathologist"]
    sales = ["sales", "marketing"]
    admin = ["administrator", "office", "admin"]
    media = ["reporter", "journalist", "media"]
    it  = ["support", "it"]
    medical = ["health", "medical", "mental", "physical","therapist", "clinical", "nursery", "nursing", "nurse", "psychologist"]
    teacher = ["teacher","lecturer", "tutor","instructor","trainer", "education", "training", "librarian", "educator",  
               "facilitator", "music", "learning", "library"]
    others = ["environmental", "environment","digital","communications","partner", "clerk", "coordinator", "visual","start-up",
               "store", "stripper", "shipping", "vet", "wedding", "brewer", "paralegal", "receptionist", "student","others",
               "cashier","intern","cook", "chef", "borrow", "entry", "adjunct", "supervisor", "superviso", "host", "artist", 
               "reception", "refurbisher", "operations", "productions", "production", "producer", "lab", "biller", "loan", 
               "line", "party", "coach", "homemaker", "goddess", "broker", "attendant", "firefighter", "executive", 
               "electrician", "assembler", "solutions", "customer", "care", "barista", "collector", "club", "ceo", "chief", 
               "case", "associate", "youth", "agent", "member", "owner", "operator", "property","ta","culinary", "server", 
               "busser", "independent", "contractor", "public", "retired", "bookseller","attorneu", "ea", "food", "maid", 
               "museum","keyholder", "cna", "experience" "package", "handler", "project",  "shift", "attorney",  "boss", 
               "interviewer", "lead", "bookkeeper", "farmer", "manager",  "senior", "driver", "paraprofessional",  "vp", 
               "flipper", "apprentice", "key", "phd", "receiver", "bakery", "concierge", "content", "worker", "delivery", 
               "freelance", "freelancer", "graduate", "employee", "head", "homebrew", "expert", "homemsker", "photographer", 
               "player", "tour", "guide", "resident", "companion", "dyer", "guest",  "head", "events", "temp",  "bid", "nanny",
               "bagger", "document", "teller", "advertising", "naturalist", "crew", "general", "transcriptionist", "in-charge",
               "front", "mason", "worship", "zookeeper", "level", "bartender", "arborist", "courier", "archaeologist", "HR", 
               "musician", "processor", "advisor", "acupuncturist", "housekeeper", "president",  "floor", "experience","csr", 
               "ranger", "esthetician", "registrar", "boxer", "director", "billing", "finance",  "landscaper", "craftsman", 
               "merchandiser",  "certified" ]
    
    title = jobtitle
    print(title)
    
        
    title = title.strip().lower()
    for i in range(len(engineer)):
        if (engineer[i] in title):
             title = "Engineer"
    for i in range(len(teacher)):
        if (teacher[i] in title):
             title = "Teacher"
    for i in range(len(account)):
        if (account[i] in title):
            title = "Accountant"
    for i in range(len(hr)):
        if (hr[i] in title):
             title = "HR"
    for i in range(len(scientist)):
        if (scientist[i] in title):
            title = "Scientist" 
    for i in range(len(sales)):
        if (sales[i] in title):
             title = "Sales"
    for i in range(len(admin)):
        if (admin[i] in title):
            title = "Admin"
    for i in range(len(media)):
        if (media[i] in title):
             title = "Media"
    for i in range(len(it)):
        if (it[i] in title):
            title = "IT"
    for i in range(len(medical)):
        if (medical[i] in title):
            title = "Medical"
    for i in range(len(others)):
        if (others[i] in title):
             title = "Others"
    
    
    return title

# %% [markdown]
# ### Creating a new column 'Job Title'

# %%
raw_data['Job Title'] = raw_data['Generic Job Title'].map(lambda x : GetJobTitle(x))
# Out:
# Medical Laboratory Technologist
# Borrow Direct Assistant
# Seasonal data entry associate
# Superviso
# Theatrical Journeyman/student
# Intern
# Software developer
# Front end cashier
# Adjunct
# graphic designer
# Research Assistant
# Collection Development Librarian
# Office Assistant
# Receptionist
# Line cook
# Study start-up associate
# Study start-up associate
# Prison Librarian
# Paralegal
# Teachers Assistant
# Administrative Assistant
# Host
# Swim instructor
# Writing tutor
# Writing Tutor
# Waiter
# Interior designer
# Distance Learning Facilitator
# journalist / reporter
# journalist / reporter
# Part-time SEO Copywriter
# Journeyman Electrician
# Admin Assistant
# Sale associate
# Member service representative
# Operations Coordinator
# student
# After School Teacher and Sweeper
# Horse Trainer
# Owner Operator
# Site Manager
# Director of Communications
# Host
# Property inspector
# TA
# Intern
# Culinary server
# Office Worker
# Senior Design Quality Engineer
# babysitter
# Busser
# Busser
# Clerk
# english teacher
# Independent Contractor
# Meat Clerk
# Public Relations Manager
# Exercise specialists
# Help Desk Tech
# Cafteria Worker (Student Manager)
# Barista
# DIGITAL MEDIA MANAGER
# Part-time freelance writer
# Part-time freelance writer
# Piano instructor
# Publicity Contact
# retired
# Server
# Store Clerk
# Supervisor
# Supervisor
# Senior Project Engineer
# Engineer
# Sales rep
# Library Assistant
# Adjunct instructor
# Caretaker
# Bookseller
# Director of Nursing
# Library Assistant
# Library Page
# Computer Scientist
# Computer Scientist
# Adjunct
# Adjunct professor
# Attorneu
# Barista
# Content Writer
# EA
# Field representative
# Fitter
# food
# freelance writer
# Graduate Assistant Coach
# Instructional assistant
# Legal Secretary
# Maid
# Museum services lead
# Pharmacy tech
# Prep cook
# Research Assistant
# student
# Student support services
# Teacher
# Teaching assistant
# Vet tech
# Keyholder
# Adjunct English Instructor
# operations
# TA
# Solar Consultant
# CNA
# Customer Service Associate
# experience embassador
# Librarian
# Package Handler
# preschool teacher
# Substitute Teacher
# Team Lead- Shoe Store
# Service Associate
# Engineer
# Project Liaison
# Ice Resurfacer/Zamboni Operator
# Senior developer
# Shift Manager
# Administrative Assistant (part time)
# Archive Assistant
# Attorney
# Boss
# ESOL teacher
# ESOL teacher
# Head Cashier/Front End Supervisor
# Interviewer
# Teaching Assistant
# access specialist II
# Library Assistant (part-time)
# Android Developer
# Teacher
# Lead
# Branch Assistant
# Adjunct Instructor
# Adjunct professor, researcher
# Bookkeeper
# Cashier
# customer service
# customer service rep
# Farmer
# Graduate Instructor
# Junior Interior Designer
# Leasing Agent
# library assistant
# Manager
# Marketing Coordinator
# Office Assistant
# Online contract worker
# Pet sitter
# Portfolio manager
# Sales consultant
# Visitor services associate
# Writer and Editor
# Cook
# Office coordinator
# barista
# Receptionist
# Records Researcher
# Senior Fellow
# Senior Fellow
# Unit Secretary
# adjunct instructor
# Assistant Manager
# copywriter
# Deli Associate
# Driver
# Farm owner
# Graduate Assistant
# Graduate Assistant Athletic Trainer
# graphic designer
# Paraprofessional
# Pharmacy Intern
# Sales Associate
# Substitute Teacher
# Server
# Prep Cook
# Shift leader
# Administrative Secretary
# bookseller
# Chiropractic Assistant
# Crew member
# Economic Development Director/Coordinator
# Firefighter/EMT
# Graduate Teaching Assistant
# Karaoke host
# Logistics Coordinator
# Logistics Coordinator
# Logistics Coordinator
# Media Aide
# Order fulfillment associate
# Sr. Product Line Manager
# Animal Care & Adoption Counselor
# Babysitter
# VP Finance
# financial manager
# Grants & Resource Specialist
# Manager on Duty
# Account executive
# aquatics instructor
# burger flipper
# Clerk
# Editor
# Facilitator I, Guest Experiences
# Game Designer
# Housing Graduate Assistant
# Juice Barista
# Math Lab Tutor
# Office Manager
# Owner
# Paraprofessional
# Preschool Teacher
# retail sales
# Sales
# Sales Representative
# Stage Manager
# Substitute teacher
# Technician
# Programs Assistant (Part-time)
# Library associate
# Inventory specialist
# Play Apprentice
# PhD student
# Office Assistant
# Utility data specialist
# Assistant Career Planner
# Admin Assistant
# Checkout coach
# Customer Service Representative
# Grad student
# Graduate research assistant
# Key Holder
# Library Assistant
# Medical technician
# Office Manager
# PhD Candidate
# receiver
# server
# Library Assistant
# manager
# Administrative Assistant
# Sales Associate
# VP product engineering
# Administrative Assitant
# Adjunct instructor
# Adjunct professor
# Assistant Bookkeeper
# Back Office
# Bakery team leader & froster
# Barn Manager
# Bus Operator
# Cashier
# Cashier
# CNA
# concierge
# Content Ceator
# Copy editor, paginator
# Deli worker
# Delivery Driver
# Dive instructor
# Founder/Executive Director
# freelance musician
# Freelancer
# Graduate Employee
# Head Turtle
# Homebrew Expert
# Homemsker
# Lecturer
# Library Assistant II
# Library Associate
# library clerk
# Men's & Women's Assistant Track and Cross Country Coach
# Museum Teacher/Planetarium Presenter
# Permit Technician
# Pharmacy intern
# Pharmacy Technician
# PhD Candidate / Teaching Assistant
# Photographer
# Physics Graduate Student
# Poker Player
# Preschool teacher
# Public Service Assistant
# Receptionist
# Reference Librarian
# Reference Librarian
# Reporter
# Research Assistant
# Research Assistant
# Sales
# Sales associate
# Sales Specialist
# Substitute teacher
# Teacher of English
# Tour Guide
# Volleyball Coach
# Waiter
# Cashier
# Cashier
# Manager
# Graduate Student
# Medically retired officer/freelance web developer
# Sales associate
# Web Application Developer
# Associate Development Director
# Customer Service Representative
# Early childhood teacher
# Office administrator
# Resident Social Companion
# Graduate teaching assistant
# Agent
# Reporter
# Reporter
# Research assistant
# Research Assistant
# Research Scientist
# Researcher
# researcher
# Resident Artist
# Server
# Server
# Shipping associate
# Social Media Manager
# Specialist
# Specialist
# Speech-Language Pathologist
# Staff writer
# store manager
# stripper
# Sushi Chef
# Systems Administrator
# Teaching Assistant, PhD student
# Tech Support
# Tutor
# Vet tech
# Veterinary Technician
# Web & Marketing Manager
# Wedding Planner
# Programs Coordinator
# Library Assistant
# Data Clerk
# Maintenance Coordinator
# Graduate Coordinator
# Administrative Assistant
# Instructional Technologist
# Student Records Specialist
# Program Coordinator
# Billing specialist
# Library Manager
# Administrative and Purchasing Coordinator
# Assistant Brewer

# %%
print(raw_data['Job Title'].unique())
# Out:
# ['Engineer' 'Others' 'Scientist' 'Admin' 'IT' 'Media' 'Sales' 'Medical']

# %% [markdown]
# ### Dropping a redundant column

# %%
raw_data.drop(['Generic Job Title'], axis = 1, inplace=True)
raw_data.head()
# Out:
#      Age                                           Industry  Salary Currency  \
# 0  18-24                                           Hospital  1000.0      USD
# 1  18-24                               on-campus employment  2000.0      USD
# 2  18-24                              Images and Data Entry  2000.0      USD
# 3  35-44                                      Retail Gocery  2240.0      USD
# 4  18-24  Currently a student, but I work in my drama de...  2900.0      USD
#
#    Experience Gender Job Title
# 0           1   Male  Engineer
# 1           1   Male    Others
# 2           1   Male    Others
# 3          11   Male    Others
# 4           1   Male    Others

# %% [markdown]
# ###  Removing precision from the values of  experience that are in fractions

# %%
raw_data['Experience'] = round(raw_data['Experience'])

# %%
raw_data
# Out:
#             Age                                           Industry   Salary  \
# 0         18-24                                           Hospital   1000.0
# 1         18-24                               on-campus employment   2000.0
# 2         18-24                              Images and Data Entry   2000.0
# 3         35-44                                      Retail Gocery   2240.0
# 4         18-24  Currently a student, but I work in my drama de...   2900.0
# 5         18-24                                        County govt   3000.0
# 6         18-24                                           Software   3000.0
# 7         55-64                                            Grocery   3150.0
# 8         25-34                                           Academia   3500.0
# 9         55-64                                   graphic designer   3500.0
# 10        18-24                                                Law   3640.0
# 11        35-44                                     Public Library   3700.0
# 12        18-24                                                NaN   3700.0
# 13        18-24                                                NaN   3800.0
# 14        18-24                                           Culinary   3840.0
# 15        35-44                                     Clinical trial   3900.0
# 16        35-44                                     Clinical trial   3900.0
# 17        25-34                                     State Employee   4100.0
# 18        25-34                                              Legal   4500.0
# 19        18-24                                           Teaching   4500.0
# 20        25-34                                          Education   4884.0
# 21        18-24                                        Restaurant    5000.0
# 22        18-24                                          Education   5000.0
# 23        45-54                                         Education    5000.0
# 24        18-24                                   Higher Education   5000.0
# 25        18-24                                       Hospitality    5140.0
# 26        35-44                                            Design    5400.0
# 27        45-54                                   Higher Education   6000.0
# 28        35-44                                              media   6000.0
# 29        35-44                                                NaN   6000.0
# ..          ...                                                ...      ...
# 847       25-34                                             Retail  30000.0
# 848       35-44                                           Chemical  30000.0
# 849       18-24                                        Health Care  30000.0
# 850       25-34                                     Private sector  30000.0
# 851       35-44                        Speech-Language Pathologist  30000.0
# 852       18-24                              Journalism /newspaper  30000.0
# 853       25-34                                            retail   30000.0
# 854  65 or over                                           printing  30000.0
# 855       25-34                         Sushi restaurant industry   30000.0
# 856       25-34                                          Education  30000.0
# 857       25-34                                           Academia  30000.0
# 858       35-44                                                 IT  30000.0
# 859       35-44                                          Education  30000.0
# 860       35-44                                Veterinary medicine  30000.0
# 861       25-34                                Veterinary Medicine  30000.0
# 862       25-34                                          Marketing  30000.0
# 863       25-34                                 Events/Hospitality  30000.0
# 864       25-34                                          Nonprofit  30030.0
# 865       25-34                                          Education  30100.0
# 866       45-54                                          Education  30350.0
# 867       25-34                                        Hospitality  30430.0
# 868       25-34                                   Higher Education  30450.0
# 869       25-34                                           Academia  30500.0
# 870       25-34                                   Higher Education  30500.0
# 871       25-34                                   Higher Education  30500.0
# 872       45-54                                         Non-Profit  30684.0
# 873       25-34                                        Accounting   30700.0
# 874       25-34                                          Education  30700.0
# 875       25-34                                Arts Administration  30720.0
# 876       25-34                                            Brewing  30720.0
#
#     Currency  Experience  Gender  Job Title
# 0        USD           1    Male   Engineer
# 1        USD           1    Male     Others
# 2        USD           1    Male     Others
# 3        USD          11    Male     Others
# 4        USD           1    Male     Others
# 5        USD           1    Male     Others
# 6        USD           4    Male   Engineer
# 7        USD          11    Male     Others
# 8        USD           6    Male     Others
# 9        USD          22    Male   Engineer
# 10       USD           1    Male  Scientist
# 11       USD          11    Male     Others
# 12       USD           1    Male      Admin
# 13       USD           1    Male     Others
# 14       USD           4  Female     Others
# 15       USD           6  Female     Others
# 16       USD           6  Female     Others
# 17       USD           6  Female     Others
# 18       USD           4  Female     Others
# 19       USD           1    Male     Others
# 20       USD           4    Male      Admin
# 21       USD           1    Male     Others
# 22       USD           6    Male     Others
# 23       USD          11    Male     Others
# 24       USD           1    Male     Others
# 25       USD           4    Male         IT
# 26       USD           4  Female   Engineer
# 27       USD          11  Female     Others
# 28       USD          11  Female      Media
# 29       USD          11    Male      Media
# ..       ...         ...     ...        ...
# 847      USD           6    Male     Others
# 848      USD          11    Male      Media
# 849      USD           1    Male   Engineer
# 850      USD           6    Male   Engineer
# 851      USD          11    Male  Scientist
# 852      USD           1    Male         IT
# 853      USD           6  Female     Others
# 854      USD          25  Female     Others
# 855      USD           4  Female     Others
# 856      USD           6  Female      Admin
# 857      USD           6    Male     Others
# 858      USD          11    Male   Engineer
# 859      USD          11    Male     Others
# 860      USD           8    Male   Engineer
# 861      USD           4    Male   Engineer
# 862      USD           6    Male      Sales
# 863      USD           6    Male     Others
# 864      USD           4    Male     Others
# 865      USD           8    Male     Others
# 866      USD          22    Male     Others
# 867      USD           4    Male     Others
# 868      USD           8  Female     Others
# 869      USD           4  Female      Admin
# 870      USD           6  Female   Engineer
# 871      USD           8  Female   Engineer
# 872      USD           8    Male     Others
# 873      USD           6    Male   Engineer
# 874      USD           4    Male     Others
# 875      USD           6    Male      Admin
# 876      USD           4    Male     Others
#
# [877 rows x 7 columns]

# %% [markdown]
# ### Label Encoding to tranform Gender and Job Title categorical data into numerics

# %%
raw_data['Gender Encoded'] = LabelEncoder().fit_transform(raw_data['Gender'])
raw_data['Job Title Encoded'] = LabelEncoder().fit_transform(raw_data['Job Title'])

# %%
raw_data
# Out:
#             Age                                           Industry   Salary  \
# 0         18-24                                           Hospital   1000.0
# 1         18-24                               on-campus employment   2000.0
# 2         18-24                              Images and Data Entry   2000.0
# 3         35-44                                      Retail Gocery   2240.0
# 4         18-24  Currently a student, but I work in my drama de...   2900.0
# 5         18-24                                        County govt   3000.0
# 6         18-24                                           Software   3000.0
# 7         55-64                                            Grocery   3150.0
# 8         25-34                                           Academia   3500.0
# 9         55-64                                   graphic designer   3500.0
# 10        18-24                                                Law   3640.0
# 11        35-44                                     Public Library   3700.0
# 12        18-24                                                NaN   3700.0
# 13        18-24                                                NaN   3800.0
# 14        18-24                                           Culinary   3840.0
# 15        35-44                                     Clinical trial   3900.0
# 16        35-44                                     Clinical trial   3900.0
# 17        25-34                                     State Employee   4100.0
# 18        25-34                                              Legal   4500.0
# 19        18-24                                           Teaching   4500.0
# 20        25-34                                          Education   4884.0
# 21        18-24                                        Restaurant    5000.0
# 22        18-24                                          Education   5000.0
# 23        45-54                                         Education    5000.0
# 24        18-24                                   Higher Education   5000.0
# 25        18-24                                       Hospitality    5140.0
# 26        35-44                                            Design    5400.0
# 27        45-54                                   Higher Education   6000.0
# 28        35-44                                              media   6000.0
# 29        35-44                                                NaN   6000.0
# ..          ...                                                ...      ...
# 847       25-34                                             Retail  30000.0
# 848       35-44                                           Chemical  30000.0
# 849       18-24                                        Health Care  30000.0
# 850       25-34                                     Private sector  30000.0
# 851       35-44                        Speech-Language Pathologist  30000.0
# 852       18-24                              Journalism /newspaper  30000.0
# 853       25-34                                            retail   30000.0
# 854  65 or over                                           printing  30000.0
# 855       25-34                         Sushi restaurant industry   30000.0
# 856       25-34                                          Education  30000.0
# 857       25-34                                           Academia  30000.0
# 858       35-44                                                 IT  30000.0
# 859       35-44                                          Education  30000.0
# 860       35-44                                Veterinary medicine  30000.0
# 861       25-34                                Veterinary Medicine  30000.0
# 862       25-34                                          Marketing  30000.0
# 863       25-34                                 Events/Hospitality  30000.0
# 864       25-34                                          Nonprofit  30030.0
# 865       25-34                                          Education  30100.0
# 866       45-54                                          Education  30350.0
# 867       25-34                                        Hospitality  30430.0
# 868       25-34                                   Higher Education  30450.0
# 869       25-34                                           Academia  30500.0
# 870       25-34                                   Higher Education  30500.0
# 871       25-34                                   Higher Education  30500.0
# 872       45-54                                         Non-Profit  30684.0
# 873       25-34                                        Accounting   30700.0
# 874       25-34                                          Education  30700.0
# 875       25-34                                Arts Administration  30720.0
# 876       25-34                                            Brewing  30720.0
#
#     Currency  Experience  Gender  Job Title  Gender Encoded  Job Title Encoded
# 0        USD           1    Male   Engineer               1                  1
# 1        USD           1    Male     Others               1                  5
# 2        USD           1    Male     Others               1                  5
# 3        USD          11    Male     Others               1                  5
# 4        USD           1    Male     Others               1                  5
# 5        USD           1    Male     Others               1                  5
# 6        USD           4    Male   Engineer               1                  1
# 7        USD          11    Male     Others               1                  5
# 8        USD           6    Male     Others               1                  5
# 9        USD          22    Male   Engineer               1                  1
# 10       USD           1    Male  Scientist               1                  7
# 11       USD          11    Male     Others               1                  5
# 12       USD           1    Male      Admin               1                  0
# 13       USD           1    Male     Others               1                  5
# 14       USD           4  Female     Others               0                  5
# 15       USD           6  Female     Others               0                  5
# 16       USD           6  Female     Others               0                  5
# 17       USD           6  Female     Others               0                  5
# 18       USD           4  Female     Others               0                  5
# 19       USD           1    Male     Others               1                  5
# 20       USD           4    Male      Admin               1                  0
# 21       USD           1    Male     Others               1                  5
# 22       USD           6    Male     Others               1                  5
# 23       USD          11    Male     Others               1                  5
# 24       USD           1    Male     Others               1                  5
# 25       USD           4    Male         IT               1                  2
# 26       USD           4  Female   Engineer               0                  1
# 27       USD          11  Female     Others               0                  5
# 28       USD          11  Female      Media               0                  3
# 29       USD          11    Male      Media               1                  3
# ..       ...         ...     ...        ...             ...                ...
# 847      USD           6    Male     Others               1                  5
# 848      USD          11    Male      Media               1                  3
# 849      USD           1    Male   Engineer               1                  1
# 850      USD           6    Male   Engineer               1                  1
# 851      USD          11    Male  Scientist               1                  7
# 852      USD           1    Male         IT               1                  2
# 853      USD           6  Female     Others               0                  5
# 854      USD          25  Female     Others               0                  5
# 855      USD           4  Female     Others               0                  5
# 856      USD           6  Female      Admin               0                  0
# 857      USD           6    Male     Others               1                  5
# 858      USD          11    Male   Engineer               1                  1
# 859      USD          11    Male     Others               1                  5
# 860      USD           8    Male   Engineer               1                  1
# 861      USD           4    Male   Engineer               1                  1
# 862      USD           6    Male      Sales               1                  6
# 863      USD           6    Male     Others               1                  5
# 864      USD           4    Male     Others               1                  5
# 865      USD           8    Male     Others               1                  5
# 866      USD          22    Male     Others               1                  5
# 867      USD           4    Male     Others               1                  5
# 868      USD           8  Female     Others               0                  5
# 869      USD           4  Female      Admin               0                  0
# 870      USD           6  Female   Engineer               0                  1
# 871      USD           8  Female   Engineer               0                  1
# 872      USD           8    Male     Others               1                  5
# 873      USD           6    Male   Engineer               1                  1
# 874      USD           4    Male     Others               1                  5
# 875      USD           6    Male      Admin               1                  0
# 876      USD           4    Male     Others               1                  5
#
# [877 rows x 9 columns]

# %% [markdown]
# ### Re-arrange the columns in a correct sequence (x, y)

# %%
raw_data = raw_data[['Experience', 'Gender', 'Gender Encoded', 'Job Title', 'Job Title Encoded', 'Salary']]
raw_data
# Out:
#      Experience  Gender  Gender Encoded  Job Title  Job Title Encoded   Salary
# 0             1    Male               1   Engineer                  1   1000.0
# 1             1    Male               1     Others                  5   2000.0
# 2             1    Male               1     Others                  5   2000.0
# 3            11    Male               1     Others                  5   2240.0
# 4             1    Male               1     Others                  5   2900.0
# 5             1    Male               1     Others                  5   3000.0
# 6             4    Male               1   Engineer                  1   3000.0
# 7            11    Male               1     Others                  5   3150.0
# 8             6    Male               1     Others                  5   3500.0
# 9            22    Male               1   Engineer                  1   3500.0
# 10            1    Male               1  Scientist                  7   3640.0
# 11           11    Male               1     Others                  5   3700.0
# 12            1    Male               1      Admin                  0   3700.0
# 13            1    Male               1     Others                  5   3800.0
# 14            4  Female               0     Others                  5   3840.0
# 15            6  Female               0     Others                  5   3900.0
# 16            6  Female               0     Others                  5   3900.0
# 17            6  Female               0     Others                  5   4100.0
# 18            4  Female               0     Others                  5   4500.0
# 19            1    Male               1     Others                  5   4500.0
# 20            4    Male               1      Admin                  0   4884.0
# 21            1    Male               1     Others                  5   5000.0
# 22            6    Male               1     Others                  5   5000.0
# 23           11    Male               1     Others                  5   5000.0
# 24            1    Male               1     Others                  5   5000.0
# 25            4    Male               1         IT                  2   5140.0
# 26            4  Female               0   Engineer                  1   5400.0
# 27           11  Female               0     Others                  5   6000.0
# 28           11  Female               0      Media                  3   6000.0
# 29           11    Male               1      Media                  3   6000.0
# ..          ...     ...             ...        ...                ...      ...
# 847           6    Male               1     Others                  5  30000.0
# 848          11    Male               1      Media                  3  30000.0
# 849           1    Male               1   Engineer                  1  30000.0
# 850           6    Male               1   Engineer                  1  30000.0
# 851          11    Male               1  Scientist                  7  30000.0
# 852           1    Male               1         IT                  2  30000.0
# 853           6  Female               0     Others                  5  30000.0
# 854          25  Female               0     Others                  5  30000.0
# 855           4  Female               0     Others                  5  30000.0
# 856           6  Female               0      Admin                  0  30000.0
# 857           6    Male               1     Others                  5  30000.0
# 858          11    Male               1   Engineer                  1  30000.0
# 859          11    Male               1     Others                  5  30000.0
# 860           8    Male               1   Engineer                  1  30000.0
# 861           4    Male               1   Engineer                  1  30000.0
# 862           6    Male               1      Sales                  6  30000.0
# 863           6    Male               1     Others                  5  30000.0
# 864           4    Male               1     Others                  5  30030.0
# 865           8    Male               1     Others                  5  30100.0
# 866          22    Male               1     Others                  5  30350.0
# 867           4    Male               1     Others                  5  30430.0
# 868           8  Female               0     Others                  5  30450.0
# 869           4  Female               0      Admin                  0  30500.0
# 870           6  Female               0   Engineer                  1  30500.0
# 871           8  Female               0   Engineer                  1  30500.0
# 872           8    Male               1     Others                  5  30684.0
# 873           6    Male               1   Engineer                  1  30700.0
# 874           4    Male               1     Others                  5  30700.0
# 875           6    Male               1      Admin                  0  30720.0
# 876           4    Male               1     Others                  5  30720.0
#
# [877 rows x 6 columns]

# %% [markdown]
# ### Data Analysis and Visualization

# %% [markdown]
# #### Getting median salaries based on Job Title

# %%
raw_data.groupby(['Job Title'])['Salary'].median()
# Out:
# Job Title
# Admin        25920.0
# Engineer     25000.0
# IT           24000.0
# Media        24000.0
# Medical      27000.0
# Others       23782.0
# Sales        24000.0
# Scientist    25000.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Data proportion based on Gender (Male or Female)

# %%
raw_data.Gender.value_counts(normalize = True)
# Out:
# Male      0.847206
# Female    0.152794
# Name: Gender, dtype: float64

# %%
raw_data.groupby(['Gender'])['Experience', 'Salary'].median()
# Out:
#         Experience   Salary
# Gender
# Female           4  25960.0
# Male             6  24000.0

# %%
raw_data.groupby(['Gender'])['Salary'].mean()
# Out:
# Gender
# Female    23459.010000
# Male      22139.619058
# Name: Salary, dtype: float64

# %%
groups = raw_data.groupby("Salary")
for name, group in groups:
    plt.plot(group["Gender Encoded"], group["Experience"], marker="o", linestyle="", label= name)
    plt.title('Salary comparison based on Experience and Gender')

# %%
raw_data.groupby(['Experience','Gender', 'Job Title'])['Salary'].median()
# Out:
# Experience  Gender  Job Title
# 1           Female  Admin        26460.0
#                     Engineer     22500.0
#                     IT           30000.0
#                     Media        30000.0
#                     Others       20548.0
#                     Sales        21500.0
#                     Scientist    26100.0
#             Male    Admin        27125.0
#                     Engineer     24900.0
#                     IT           21000.0
#                     Media        20000.0
#                     Medical      30000.0
#                     Others       22000.0
#                     Sales        20500.0
#                     Scientist    27375.0
# 4           Female  Admin        27900.0
#                     Engineer     24000.0
#                     IT           27000.0
#                     Media        30000.0
#                     Medical      30000.0
#                     Others       27000.0
#                     Sales        30000.0
#             Male    Admin        25250.0
#                     Engineer     26500.0
#                     IT           25000.0
#                     Media        24000.0
#                     Medical      27000.0
#                     Others       24000.0
#                     Sales        30000.0
#                     Scientist    26000.0
#                                   ...
# 11          Female  Engineer     27000.0
#                     Media         6000.0
#                     Medical      30000.0
#                     Others       25840.0
#             Male    Admin        23000.0
#                     Engineer     27000.0
#                     IT           20000.0
#                     Media        24000.0
#                     Others       23000.0
#                     Sales        19000.0
#                     Scientist    29250.0
# 22          Female  Admin        30000.0
#                     IT           16918.5
#                     Others       23500.0
#             Male    Admin        20800.0
#                     Engineer     25000.0
#                     IT           26000.0
#                     Others       26000.0
#                     Sales        10500.0
#                     Scientist    15000.0
# 25          Female  Others       30000.0
#                     Sales        25400.0
#             Male    Admin        25000.0
#                     Engineer     19500.0
#                     IT           27000.0
#                     Medical      24000.0
#                     Others       20500.0
# 30          Male    Admin         6720.0
#                     Engineer     30000.0
#                     Others       24003.0
# Name: Salary, Length: 85, dtype: float64

# %% [markdown]
# ### Getting the mean of salaries based on each years of experience

# %%
dict = (raw_data.groupby(['Experience'])['Salary'].mean().astype(int)).to_dict()
print(dict)
# Out:
# {1: 21095, 4: 23560, 6: 21444, 8: 24046, 11: 21487, 22: 22547, 25: 23264, 30: 21121}

# %%
for k, v in dict.items():
    raw_data.loc[raw_data.Experience == k, "Salary"] = v
# Out:
# C:\Users\simra\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ### Removing Gender and Job Title column

# %%
raw_data.drop(['Gender'], axis = 1, inplace=True)
raw_data.drop(['Job Title'], axis = 1, inplace=True)
# Out:
# C:\Users\simra\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ### Processed data path

# %%
processed_data_path = os.path.join(os.path.pardir, 'data', 'processed')
write_processed_data_path = os.path.join(processed_data_path, 'processed_data.xlsx')
raw_data.to_excel(write_processed_data_path, index=False)

# %% [markdown]
# ### Read processed data to feed into the model

# %%
processed_data = pd.read_excel(write_processed_data_path)

# %% [markdown]
# ### Splitting the whole data into training and testing batches using train_test_split

# %%
train, test = train_test_split(processed_data, test_size = 0.2)
print("Training size: {}, Test Size {}".format(len(train), len(test)))
# Out:
# Training size: 701, Test Size 176

# %% [markdown]
# ### Defining train and test data X and y features

# %%
features = ['Experience', 'Gender Encoded', 'Job Title Encoded']
X_train = train[features]
y_train = train['Salary']

X_test = test[features]
y_test = test['Salary']

# %% [markdown]
# ### Creating the model

# %%
clf = RandomForestRegressor(n_estimators=100, random_state=0)

# %% [markdown]
# ### Training the model using fit()

# %%
clf = clf.fit(X_train, y_train)

# %% [markdown]
# ### Predict based on a new set of input variables

# %%
y_pred = clf.predict(X_test)

# %%
print(y_pred)
print(y_test)
# Out:
# [21095.   24046.   21095.   23560.   21095.   21487.   24046.   21444.
#  21444.   24046.   21444.   23560.   23560.   24046.   21487.   21095.
#  23560.   24046.   21095.   24046.   21444.   21444.   21095.   21444.
#  22547.   23560.   23560.   23560.   22547.   21487.   21444.   23560.
#  23560.   21487.   21095.   21095.   21095.   23560.   21095.   23560.
#  24046.   21444.   21444.   24046.   23560.   21095.   21095.   21444.
#  23264.   21487.   21095.   21487.   21095.   23560.   21444.   21444.
#  23560.   21095.   23560.   21444.   21095.   22547.   21444.   21444.
#  23560.   21444.   23560.   21487.   23560.   23560.   23560.   22547.
#  21095.   24046.   21095.   23560.   24046.   21487.   21487.   24046.
#  22547.   24046.   23560.   23560.   21487.   21487.   21444.   21444.
#  21487.   23560.   24046.   23264.   23264.   21095.   21487.   21487.
#  21095.   22547.   21487.   21444.   24046.   21487.   21444.   21095.
#  21444.   23560.   22547.   23264.   23560.   21095.   21095.   21487.
#  21487.   23560.   22547.   21444.   21095.   23560.   23264.   21487.
#  23264.   21095.   21487.   21095.   23560.   23560.   21095.   23560.
#  23560.   23560.   24046.   23560.   22547.   21444.   21487.   21095.
#  21095.   23560.   21095.   23560.   21163.86 21095.   23560.   24046.
#  21487.   23560.   21095.   21444.   21444.   21095.   23560.   23560.
#  21487.   23560.   21487.   21487.   23264.   22547.   23560.   21487.
#  21095.   24046.   21487.   21095.   21095.   21095.   23560.   21444.
#  21444.   21487.   21095.   24046.   21487.   21444.   21444.   21444.  ]
# 30     21095
# 216    24046
# 375    21095
# 630    23560
# 179    21095
# 493    21487
# 865    24046
# 72     21444
# 193    21444
# 552    24046
# 164    21444
# 564    23560
# 6      23560
# 84     24046
# 817    21487
# 317    21095
# 708    23560
# 786    24046
# 832    21095
# 401    24046
# 561    21444
# 285    21444
# 829    21095
# 521    21444
# 123    22547
# 453    23560
# 26     23560
# 802    23560
# 466    22547
# 812    21487
#        ...
# 559    21095
# 133    21444
# 429    21444
# 482    21095
# 38     23560
# 770    23560
# 858    21487
# 329    23560
# 815    21487
# 54     21487
# 582    23264
# 134    22547
# 768    23560
# 98     21487
# 514    21095
# 808    24046
# 787    21487
# 351    21095
# 436    21095
# 700    21095
# 590    23560
# 114    21444
# 251    21444
# 794    21487
# 534    21095
# 661    24046
# 381    21487
# 201    21444
# 190    21444
# 632    21444
# Name: Salary, Length: 176, dtype: int64

# %% [markdown]
# ### Model Metrics: Errors

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.24352272727273058
# Mean Squared Error: 10.437384090909374
# Root Mean Squared Error: 3.230694057150781
